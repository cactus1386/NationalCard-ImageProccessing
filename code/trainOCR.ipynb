# %% [markdown]
# <a href="https://colab.research.google.com/github/cactus1386/NationalCard-ImageProccessing/blob/main/trainOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from PIL import Image
import os
from torch.utils.data import random_split
import yaml

# %%
class CNNBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, padding=1):
        super(CNNBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, padding=padding)
        self.bn = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = nn.functional.relu(x)
        return x

# %%
class CRNN(nn.Module):
    def __init__(self, n_channels, num_classes, map2seq_in_dim, map2seq_out_dim, rnn_dim):
        super(CRNN, self).__init__()
        self.cnn = nn.ModuleDict({
            '0': CNNBlock(n_channels, 64),
            '2': CNNBlock(64, 128),
            '4': CNNBlock(128, 256),
            '5': CNNBlock(256, 256),
            '7': CNNBlock(256, 512),
            '8': CNNBlock(512, 512),
            '10': CNNBlock(512, 512, kernel_size=3, padding=1)
        })
        self.map2seq = nn.Linear(map2seq_in_dim, map2seq_out_dim)
        self.rnn1 = nn.LSTM(map2seq_out_dim, rnn_dim, bidirectional=True, batch_first=True)
        self.rnn2 = nn.LSTM(rnn_dim * 2, rnn_dim, bidirectional=True, batch_first=True)
        self.classifier = nn.Linear(rnn_dim * 2, num_classes)

    def forward(self, x):
        for key in sorted(self.cnn.keys(), key=lambda k: int(k)):
            x = self.cnn[key](x)
            if key in ['0', '2']:
                x = nn.functional.max_pool2d(x, 2)
            elif key in ['5', '8']:
                x = nn.functional.max_pool2d(x, (2, 1))
        batch, channels, height, width = x.size()
        x = x.permute(0, 3, 1, 2).reshape(batch, width, -1)
        x = self.map2seq(x)
        x, _ = self.rnn1(x)
        x, _ = self.rnn2(x)
        x = self.classifier(x)
        return x

# %%
def preprocess_image(image_path):
    with open("/content/drive/MyDrive/crnn-fa-printed-96-long/preprocessor/image_processor_config.yaml", "r") as f:
        config = yaml.safe_load(f)

    transform = transforms.Compose([
        transforms.Grayscale(num_output_channels=1),
        transforms.Resize((32, 384)),
        transforms.Lambda(lambda x: x.transpose(Image.FLIP_LEFT_RIGHT) if config["mirror"] else x),
        transforms.ToTensor(),
        transforms.Normalize(mean=config["mean"], std=config["std"]),
        transforms.Lambda(lambda x: x * config["rescale"])
    ])
    image = Image.open(image_path).convert("L")
    return transform(image)

# %%
class NewOCRDataset(Dataset):
    def __init__(self, image_dir):
        self.image_dir = image_dir
        self.image_paths = [os.path.join(image_dir, fname) for fname in os.listdir(image_dir) if fname.endswith(('.png', '.jpg', '.jpeg'))]

        with open("/content/drive/MyDrive/crnn-fa-printed-96-long/model_config.yaml", "r") as f:
            config = yaml.safe_load(f)
        self.char2id = {char: idx for idx, char in config["id2label"].items()}

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = preprocess_image(img_path)

        label = os.path.splitext(os.path.basename(img_path))[0]
        label = format_label(label)

        label_ids = [self.char2id.get(c, 0) for c in label]
        return image, torch.tensor(label_ids, dtype=torch.long), len(label_ids)

# %%
def collate_fn(batch):
    images, targets, target_lengths = zip(*batch)
    images = torch.stack(images, dim=0)
    targets = [t.clone().detach() for t in targets]
    target_lengths = torch.tensor(target_lengths, dtype=torch.long)
    return images, targets, target_lengths

# %%
def train_model(model, train_dataloader, val_dataloader, num_epochs=15, patience=3):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    criterion = nn.CTCLoss(blank=0, zero_infinity=True)
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    best_val_loss = float('inf')
    epochs_no_improve = 0
    best_model_path = "/content/drive/MyDrive/models/best_finetuned.pt"

    for epoch in range(num_epochs):
        # آموزش
        model.train()
        total_train_loss = 0
        for batch_idx, (images, targets, target_lengths) in enumerate(train_dataloader):
            images = images.to(device)
            targets = torch.cat(targets).to(device)
            target_lengths = target_lengths.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            outputs = outputs.log_softmax(2)
            outputs = outputs.permute(1, 0, 2)
            input_lengths = torch.full((images.size(0),), outputs.size(0), dtype=torch.long).to(device)
            loss = criterion(outputs, targets, input_lengths, target_lengths)

            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()
            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}], Train Loss: {loss.item():.4f}")

        avg_train_loss = total_train_loss / len(train_dataloader)
        print(f"Epoch [{epoch+1}/{num_epochs}] completed, Avg Train Loss: {avg_train_loss:.4f}")

        # ارزیابی روی validation
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for images, targets, target_lengths in val_dataloader:
                images = images.to(device)
                targets = torch.cat(targets).to(device)
                target_lengths = target_lengths.to(device)

                outputs = model(images)
                outputs = outputs.log_softmax(2)
                outputs = outputs.permute(1, 0, 2)
                input_lengths = torch.full((images.size(0),), outputs.size(0), dtype=torch.long).to(device)
                loss = criterion(outputs, targets, input_lengths, target_lengths)

                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_dataloader)
        print(f"Epoch [{epoch+1}/{num_epochs}] completed, Avg Val Loss: {avg_val_loss:.4f}")

        # Early Stopping
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), best_model_path)
            print(f"بهترین مدل ذخیره شد: {best_model_path}, Val Loss: {best_val_loss:.4f}")
        else:
            epochs_no_improve += 1
            print(f"لاس validation بهبود نیافت ({epochs_no_improve}/{patience})")
            if epochs_no_improve >= patience:
                print("Early stopping! آموزش متوقف شد.")
                break

    # ذخیره مدل نهایی
    torch.save(model.state_dict(), "/content/drive/MyDrive/models/finetuned.pt")
    print("مدل نهایی ذخیره شد: finetuned.pt")

# %%
def format_label(label):
    label = label.rstrip('bt')

    if label.isdigit():
        if len(label) == 8:
            year = label[:4]
            month = label[4:6]
            day = label[6:]
            return f"{year}/{month}/{day}"
        elif len(label) == 10:  # اعداد 10 رقمی
            return label
    return label

# %%
image_dir = "/content/drive/MyDrive/ImageGenerate/images"

dataset = NewOCRDataset(image_dir)

total_size = len(dataset)
train_size = int(0.7 * total_size)
val_size = int(0.15 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_dataloader = DataLoader(train_dataset, batch_size=2, shuffle=True, collate_fn=collate_fn)
val_dataloader = DataLoader(val_dataset, batch_size=2, shuffle=False, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, batch_size=2, shuffle=False, collate_fn=collate_fn)

# %%
with open("/content/drive/MyDrive/crnn-fa-printed-96-long/model_config.yaml", "r") as f:
    config = yaml.safe_load(f)

model = CRNN(
    n_channels=config["n_channels"],
    map2seq_in_dim=config["map2seq_in_dim"],
    map2seq_out_dim=config["map2seq_out_dim"],
    rnn_dim=config["rnn_dim"],
    num_classes=len(config["id2label"])
)

model.load_state_dict(torch.load("/content/drive/MyDrive/crnn-fa-printed-96-long/model.pt", map_location="cpu"))
model.eval()

train_model(model, train_dataloader, val_dataloader, num_epochs=20, patience=3)

model.eval()
total_test_loss = 0
with torch.no_grad():
    for images, targets, target_lengths in test_dataloader:
        targets = torch.cat(targets)

        outputs = model(images)
        outputs = outputs.log_softmax(2)
        outputs = outputs.permute(1, 0, 2)
        input_lengths = torch.full((images.size(0),), outputs.size(0), dtype=torch.long)
        loss = criterion(outputs, targets, input_lengths, target_lengths)

        total_test_loss += loss.item()

avg_test_loss = total_test_loss / len(test_dataloader)
print(f"Test Loss: {avg_test_loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch [17/20], Batch [985], Train Loss: 0.0143
# Epoch [17/20], Batch [986], Train Loss: 0.0056
# Epoch [17/20], Batch [987], Train Loss: 0.6213
# Epoch [17/20], Batch [988], Train Loss: 0.8567
# Epoch [17/20], Batch [989], Train Loss: 0.2643
# Epoch [17/20], Batch [990], Train Loss: 0.0051
# Epoch [17/20], Batch [991], Train Loss: 0.5215
# Epoch [17/20], Batch [992], Train Loss: 0.0038
# Epoch [17/20], Batch [993], Train Loss: 0.0101
# Epoch [17/20], Batch [994], Train Loss: 0.0059
# Epoch [17/20], Batch [995], Train Loss: 0.1762
# Epoch [17/20], Batch [996], Train Loss: 0.0196
# Epoch [17/20], Batch [997], Train Loss: 0.6033
# Epoch [17/20], Batch [998], Train Loss: 0.0136
# Epoch [17/20], Batch [999], Train Loss: 0.3120
# Epoch [17/20], Batch [1000], Train Loss: 0.0198
# Epoch [17/20], Batch [1001], Train Loss: 0.0091
# Epoch [17/20], Batch [1002], Train Loss: 0.0080
# Epoch [17/20], Batch [1003], Train Loss: 0.0156
# Epoch [17/20], Batch [1004], Train Loss: 0.0071
# Epoch [17/20], Batch [1005], Train Loss: 0.0104
# Epoch [17/20], Batch [1006], Train Loss: 0.3711
# Epoch [17/20], Batch [1007], Train Loss: -0.1241
# Epoch [17/20], Batch [1008], Train Loss: 0.0032
# Epoch [17/20], Batch [1009], Train Loss: 0.0038
# Epoch [17/20], Batch [1010], Train Loss: 0.2091
# Epoch [17/20], Batch [1011], Train Loss: 0.0018
# Epoch [17/20], Batch [1012], Train Loss: 0.2102
# Epoch [17/20], Batch [1013], Train Loss: 0.0015
# Epoch [17/20], Batch [1014], Train Loss: 0.0073
# Epoch [17/20], Batch [1015], Train Loss: 0.0559
# Epoch [17/20], Batch [1016], Train Loss: 0.2992
# Epoch [17/20], Batch [1017], Train Loss: 0.2932
# Epoch [17/20], Batch [1018], Train Loss: 0.1701
# Epoch [17/20], Batch [1019], Train Loss: 0.0088
# Epoch [17/20], Batch [1020], Train Loss: 0.8070
# Epoch [17/20], Batch [1021], Train Loss: 0.0008
# Epoch [17/20], Batch [1022], Train Loss: 0.6180
# Epoch [17/20], Batch [1023], Train Loss: 0.7553
# Epoch [17/20], Batch [1024], Train Loss: 0.0052
# Epoch [17/20], Batch [1025], Train Loss: 0.3387
# Epoch [18/20], Batch [120], Train Loss: 0.0225
# Epoch [18/20], Batch [121], Train Loss: 0.0228
# Epoch [18/20], Batch [122], Train Loss: 0.0026
# Epoch [18/20], Batch [123], Train Loss: 0.0062
# Epoch [18/20], Batch [124], Train Loss: 0.7477
# Epoch [18/20], Batch [125], Train Loss: 0.5915
# Epoch [18/20], Batch [126], Train Loss: 0.0070
# Epoch [18/20], Batch [127], Train Loss: 0.2277
# Epoch [18/20], Batch [128], Train Loss: 0.0172
# Epoch [18/20], Batch [129], Train Loss: 0.1749
# Epoch [18/20], Batch [130], Train Loss: 0.6685
# Epoch [18/20], Batch [131], Train Loss: 0.1682
# Epoch [18/20], Batch [132], Train Loss: 0.0027
# Epoch [18/20], Batch [133], Train Loss: 0.4096
# Epoch [18/20], Batch [134], Train Loss: 0.1564
# Epoch [18/20], Batch [135], Train Loss: 0.0027
# Epoch [18/20], Batch [136], Train Loss: 0.5574
# Epoch [18/20], Batch [137], Train Loss: 0.0054
# Epoch [18/20], Batch [138], Train Loss: 0.0030
# Epoch [18/20], Batch [139], Train Loss: 0.0097
# Epoch [18/20], Batch [140], Train Loss: 0.3827
# Epoch [18/20], Batch [141], Train Loss: 0.5792
# Epoch [18/20], Batch [142], Train Loss: 0.0137
# Epoch [18/20], Batch [143], Train Loss: 0.0136
# Epoch [18/20], Batch [144], Train Loss: 0.0073
# Epoch [18/20], Batch [145], Train Loss: 0.0148
# Epoch [18/20], Batch [146], Train Loss: 0.0147
# Epoch [18/20], Batch [147], Train Loss: 0.3439
# Epoch [18/20], Batch [148], Train Loss: 0.6209
# Epoch [18/20], Batch [149], Train Loss: 0.0021
# Epoch [18/20], Batch [150], Train Loss: 0.0015
# Epoch [18/20], Batch [151], Train Loss: 0.3980
# Epoch [18/20], Batch [152], Train Loss: 0.4594
# Epoch [18/20], Batch [153], Train Loss: -0.0899
# Epoch [18/20], Batch [154], Train Loss: 0.0107
# Epoch [18/20], Batch [155], Train Loss: 0.0049
# Epoch [18/20], Batch [156], Train Loss: 0.0003
# Epoch [18/20], Batch [157], Train Loss: 0.0039
# Epoch [18/20], Batch [158], Train Loss: 1.0345
# Epoch [18/20], Batch [159], Train Loss: 0.0016
# Epoch [18/20], Batch [160], Train Loss: 0.1474
# Epoch [18/20], Batch [161], Train Loss: 0.0057
# Epoch [18/20], Batch [162], Train Loss: 0.0124
# Epoch [18/20], Batch [163], Train Loss: 0.0051
# Epoch [18/20], Batch [164], Train Loss: 0.0117
# Epoch [18/20], Batch [165], Train Loss: 0.0051
# Epoch [18/20], Batch [166], Train Loss: 0.0153
# Epoch [18/20], Batch [167], Train Loss: 0.3721
# Epoch [18/20], Batch [168], Train Loss: 0.5927
# Epoch [18/20], Batch [169], Train Loss: 0.0469
# Epoch [18/20], Batch [170], Train Loss: 0.3462
# Epoch [18/20], Batch [171], Train Loss: 0.4112
# Epoch [18/20], Batch [172], Train Loss: 0.0069
# Epoch [18/20], Batch [173], Train Loss: 0.2437
# Epoch [18/20], Batch [174], Train Loss: 0.0100
# Epoch [18/20], Batch [175], Train Loss: 0.7304
# Epoch [18/20], Batch [176], Train Loss: 0.0086
# Epoch [18/20], Batch [177], Train Loss: 0.0135
# Epoch [18/20], Batch [178], Train Loss: 0.0198
# Epoch [18/20], Batch [179], Train Loss: 0.6592
# Epoch [18/20], Batch [180], Train Loss: 0.0098
# Epoch [18/20], Batch [181], Train Loss: 0.4188
# Epoch [18/20], Batch [182], Train Loss: 0.0077
# Epoch [18/20], Batch [183], Train Loss: 0.0048
# Epoch [18/20], Batch [184], Train Loss: 0.0069
# Epoch [18/20], Batch [185], Train Loss: 0.3765
# Epoch [18/20], Batch [186], Train Loss: 0.0063
# Epoch [18/20], Batch [187], Train Loss: 0.1467
# Epoch [18/20], Batch [188], Train Loss: 0.2652
# Epoch [18/20], Batch [189], Train Loss: 0.0031
# Epoch [18/20], Batch [190], Train Loss: 0.3792
# Epoch [18/20], Batch [191], Train Loss: 0.3188
# Epoch [18/20], Batch [192], Train Loss: 0.0078
# Epoch [18/20], Batch [193], Train Loss: 0.2562
# Epoch [18/20], Batch [194], Train Loss: 0.0094
# Epoch [18/20], Batch [195], Train Loss: 0.1937
# Epoch [18/20], Batch [196], Train Loss: 0.0101
# Epoch [18/20], Batch [197], Train Loss: 0.2592
# Epoch [18/20], Batch [198], Train Loss: 0.3181
# Epoch [18/20], Batch [199], Train Loss: 0.3574
# Epoch [18/20], Batch [200], Train Loss: 0.2770
# Epoch [18/20], Batch [201], Train Loss: 0.0183
# Epoch [18/20], Batch [202], Train Loss: 0.0066
# Epoch [18/20], Batch [203], Train Loss: 0.0108
# Epoch [18/20], Batch [204], Train Loss: 0.8401
# Epoch [18/20], Batch [205], Train Loss: 0.0096
# Epoch [18/20], Batch [206], Train Loss: -0.0964
# Epoch [18/20], Batch [207], Train Loss: 0.0120
# Epoch [18/20], Batch [208], Train Loss: 0.0844
# Epoch [18/20], Batch [209], Train Loss: 0.1468
# Epoch [18/20], Batch [210], Train Loss: 0.0149
# Epoch [18/20], Batch [211], Train Loss: 0.0186
# Epoch [18/20], Batch [212], Train Loss: 0.3258
# Epoch [18/20], Batch [213], Train Loss: 0.0141
# Epoch [18/20], Batch [214], Train Loss: 0.0065
# Epoch [18/20], Batch [215], Train Loss: 0.2388
# Epoch [18/20], Batch [216], Train Loss: 0.1879
# Epoch [18/20], Batch [217], Train Loss: 0.0025
# Epoch [18/20], Batch [218], Train Loss: 0.0053
# Epoch [18/20], Batch [219], Train Loss: 0.0071
# Epoch [18/20], Batch [220], Train Loss: 0.2075
# Epoch [18/20], Batch [221], Train Loss: 0.2742
# Epoch [18/20], Batch [222], Train Loss: 0.1894
# Epoch [18/20], Batch [223], Train Loss: 0.0091
# Epoch [18/20], Batch [224], Train Loss: 0.5201
# Epoch [18/20], Batch [225], Train Loss: 0.0059
# Epoch [18/20], Batch [226], Train Loss: 0.1710
# Epoch [18/20], Batch [227], Train Loss: 0.0028
# Epoch [18/20], Batch [228], Train Loss: 0.0385
# Epoch [18/20], Batch [229], Train Loss: 0.0067
# Epoch [18/20], Batch [230], Train Loss: 0.1586
# Epoch [18/20], Batch [231], Train Loss: 0.2124
# Epoch [18/20], Batch [232], Train Loss: 0.2278
# Epoch [18/20], Batch [233], Train Loss: 0.0045
# Epoch [18/20], Batch [234], Train Loss: 0.0048
# Epoch [18/20], Batch [235], Train Loss: 0.1364
# Epoch [18/20], Batch [236], Train Loss: 0.4845
# Epoch [18/20], Batch [237], Train Loss: 0.0110
# Epoch [18/20], Batch [238], Train Loss: 0.2269
# Epoch [18/20], Batch [239], Train Loss: 0.0090
# Epoch [18/20], Batch [240], Train Loss: 0.0024
# Epoch [18/20], Batch [241], Train Loss: 0.0050
# Epoch [18/20], Batch [242], Train Loss: 0.1366
# Epoch [18/20], Batch [243], Train Loss: 0.3396
# Epoch [18/20], Batch [244], Train Loss: 0.0250
# Epoch [18/20], Batch [245], Train Loss: 0.0048
# Epoch [18/20], Batch [246], Train Loss: 0.0054
# Epoch [18/20], Batch [247], Train Loss: 0.1752
# Epoch [18/20], Batch [248], Train Loss: 0.2487
# Epoch [18/20], Batch [249], Train Loss: 0.0120
# Epoch [18/20], Batch [250], Train Loss: 0.1867
# Epoch [18/20], Batch [251], Train Loss: 0.0037
# Epoch [18/20], Batch [252], Train Loss: 0.2274
# Epoch [18/20], Batch [253], Train Loss: 0.1976
# Epoch [18/20], Batch [254], Train Loss: 0.0077
# Epoch [18/20], Batch [255], Train Loss: 0.0034
# Epoch [18/20], Batch [256], Train Loss: 0.0563
# Epoch [18/20], Batch [257], Train Loss: 0.0146
# Epoch [18/20], Batch [258], Train Loss: 0.0019
# Epoch [18/20], Batch [259], Train Loss: 0.4469
# Epoch [18/20], Batch [260], Train Loss: 0.0065
# Epoch [18/20], Batch [261], Train Loss: 0.1087
# Epoch [18/20], Batch [262], Train Loss: 0.0045
# Epoch [18/20], Batch [263], Train Loss: 0.7945
# Epoch [18/20], Batch [264], Train Loss: 0.0219
# Epoch [18/20], Batch [265], Train Loss: 0.0030
# Epoch [18/20], Batch [266], Train Loss: 0.0038
# Epoch [18/20], Batch [267], Train Loss: 0.0041
# Epoch [18/20], Batch [268], Train Loss: 0.1495
# Epoch [18/20], Batch [269], Train Loss: 0.0010
# Epoch [18/20], Batch [270], Train Loss: -0.2242
# Epoch [18/20], Batch [271], Train Loss: 0.0050
# Epoch [18/20], Batch [272], Train Loss: 0.0038
# Epoch [18/20], Batch [273], Train Loss: 0.0063
# Epoch [18/20], Batch [274], Train Loss: 0.3352
# Epoch [18/20], Batch [275], Train Loss: 0.0119
# Epoch [18/20], Batch [276], Train Loss: 0.2167
# Epoch [18/20], Batch [277], Train Loss: 0.0089
# Epoch [18/20], Batch [278], Train Loss: 0.2204
# Epoch [18/20], Batch [279], Train Loss: 0.3578
# Epoch [18/20], Batch [280], Train Loss: 0.6192
# Epoch [18/20], Batch [281], Train Loss: 0.0063
# Epoch [18/20], Batch [282], Train Loss: 0.0172
# Epoch [18/20], Batch [283], Train Loss: 0.0119
# Epoch [18/20], Batch [284], Train Loss: 0.0009
# Epoch [18/20], Batch [285], Train Loss: 0.2282
# Epoch [18/20], Batch [286], Train Loss: 0.3797
# Epoch [18/20], Batch [287], Train Loss: 0.0101
# Epoch [18/20], Batch [288], Train Loss: 0.0078
# Epoch [18/20], Batch [289], Train Loss: 0.2471
# Epoch [18/20], Batch [290], Train Loss: 0.3502
# Epoch [18/20], Batch [291], Train Loss: 0.0207
# Epoch [18/20], Batch [292], Train Loss: 0.0343
# Epoch [18/20], Batch [293], Train Loss: 0.4206
# Epoch [18/20], Batch [294], Train Loss: 0.3232
# Epoch [18/20], Batch [295], Train Loss: 0.0017
# Epoch [18/20], Batch [296], Train Loss: 0.0141
# Epoch [18/20], Batch [297], Train Loss: 0.2560
# Epoch [18/20], Batch [298], Train Loss: 0.0049
# Epoch [18/20], Batch [299], Train Loss: 0.0196
# Epoch [18/20], Batch [300], Train Loss: 0.0076
# Epoch [18/20], Batch [301], Train Loss: 0.0789
# Epoch [18/20], Batch [302], Train Loss: 0.0137
# Epoch [18/20], Batch [303], Train Loss: 0.0869
# Epoch [18/20], Batch [304], Train Loss: 0.1159
# Epoch [18/20], Batch [305], Train Loss: 0.0026
# Epoch [18/20], Batch [306], Train Loss: 0.0041
# Epoch [18/20], Batch [307], Train Loss: 0.0047
# Epoch [18/20], Batch [308], Train Loss: 0.0013
# Epoch [18/20], Batch [309], Train Loss: 1.0545
# Epoch [18/20], Batch [310], Train Loss: 0.1709
# Epoch [18/20], Batch [311], Train Loss: 0.4655
# Epoch [18/20], Batch [312], Train Loss: 0.0073
# Epoch [18/20], Batch [313], Train Loss: 0.2587
# Epoch [18/20], Batch [314], Train Loss: 0.0183
# Epoch [18/20], Batch [315], Train Loss: 0.1257
# Epoch [18/20], Batch [316], Train Loss: 0.0044
# Epoch [18/20], Batch [317], Train Loss: -0.5567
# Epoch [18/20], Batch [318], Train Loss: 0.6458
# Epoch [18/20], Batch [319], Train Loss: 0.0079
# Epoch [18/20], Batch [320], Train Loss: 0.2468
# Epoch [18/20], Batch [321], Train Loss: 0.1145
# Epoch [18/20], Batch [322], Train Loss: 0.0061
# Epoch [18/20], Batch [323], Train Loss: 0.0018
# Epoch [18/20], Batch [324], Train Loss: 0.0088
# Epoch [18/20], Batch [325], Train Loss: 0.0071
# Epoch [18/20], Batch [326], Train Loss: 0.0006
# Epoch [18/20], Batch [327], Train Loss: 0.0030
# Epoch [18/20], Batch [328], Train Loss: 0.2134
# Epoch [18/20], Batch [329], Train Loss: 0.0131
# Epoch [18/20], Batch [330], Train Loss: 0.0050
# Epoch [18/20], Batch [331], Train Loss: 0.1153
# Epoch [18/20], Batch [332], Train Loss: 0.0177
# Epoch [18/20], Batch [333], Train Loss: -0.3758
# Epoch [18/20], Batch [334], Train Loss: 0.0051
# Epoch [18/20], Batch [335], Train Loss: 0.1050
# Epoch [18/20], Batch [336], Train Loss: 0.0066
# Epoch [18/20], Batch [337], Train Loss: 0.1901
# Epoch [18/20], Batch [338], Train Loss: 0.2125
# Epoch [18/20], Batch [339], Train Loss: 0.0020
# Epoch [18/20], Batch [395], Train Loss: 0.0013
# Epoch [18/20], Batch [396], Train Loss: 0.5719
# Epoch [18/20], Batch [397], Train Loss: 0.1284
# Epoch [18/20], Batch [398], Train Loss: 0.2751
# Epoch [18/20], Batch [399], Train Loss: 0.1828
# Epoch [18/20], Batch [400], Train Loss: 0.0864
# Epoch [18/20], Batch [401], Train Loss: 0.1241
# Epoch [18/20], Batch [402], Train Loss: 0.0170
# Epoch [18/20], Batch [403], Train Loss: 0.0135
# Epoch [18/20], Batch [404], Train Loss: 0.0053
# Epoch [18/20], Batch [405], Train Loss: 0.3571
# Epoch [18/20], Batch [406], Train Loss: 0.0259
# Epoch [18/20], Batch [407], Train Loss: 0.4893
# Epoch [18/20], Batch [408], Train Loss: 0.0037
# Epoch [18/20], Batch [409], Train Loss: 0.0492
# Epoch [18/20], Batch [410], Train Loss: 0.0083
# Epoch [18/20], Batch [411], Train Loss: 0.0049
# Epoch [18/20], Batch [412], Train Loss: 0.0043
# Epoch [18/20], Batch [413], Train Loss: 0.0075
# Epoch [18/20], Batch [414], Train Loss: 0.2042
# Epoch [18/20], Batch [415], Train Loss: 0.2004
# Epoch [18/20], Batch [416], Train Loss: 0.0136
# Epoch [18/20], Batch [417], Train Loss: 0.0226
# Epoch [18/20], Batch [418], Train Loss: 0.3112
# Epoch [18/20], Batch [419], Train Loss: 0.0150
# Epoch [18/20], Batch [420], Train Loss: 0.0042
# Epoch [18/20], Batch [421], Train Loss: 0.0025
# Epoch [18/20], Batch [422], Train Loss: 0.0040
# Epoch [18/20], Batch [423], Train Loss: 0.2388
# Epoch [18/20], Batch [424], Train Loss: 0.0066
# Epoch [18/20], Batch [425], Train Loss: 0.1699
# Epoch [18/20], Batch [426], Train Loss: 0.9803
# Epoch [18/20], Batch [427], Train Loss: 0.0043
# Epoch [18/20], Batch [428], Train Loss: 0.5518
# Epoch [18/20], Batch [429], Train Loss: 0.0056
# Epoch [18/20], Batch [430], Train Loss: 0.0046
# Epoch [18/20], Batch [431], Train Loss: 0.0016
# Epoch [18/20], Batch [432], Train Loss: 0.3331
# Epoch [18/20], Batch [433], Train Loss: 0.0087
# Epoch [18/20], Batch [434], Train Loss: 0.0069
# Epoch [18/20], Batch [435], Train Loss: 0.0014
# Epoch [18/20], Batch [436], Train Loss: 0.0103
# Epoch [18/20], Batch [437], Train Loss: -0.2250
# Epoch [18/20], Batch [438], Train Loss: 0.3586
# Epoch [18/20], Batch [439], Train Loss: 0.0134
# Epoch [18/20], Batch [440], Train Loss: 0.3030
# Epoch [18/20], Batch [441], Train Loss: 0.3463
# Epoch [18/20], Batch [442], Train Loss: 0.5860
# Epoch [18/20], Batch [443], Train Loss: 0.0027
# Epoch [18/20], Batch [444], Train Loss: 0.0109
# Epoch [18/20], Batch [445], Train Loss: 0.0048
# Epoch [18/20], Batch [446], Train Loss: 0.0075
# Epoch [18/20], Batch [447], Train Loss: 0.2465
# Epoch [18/20], Batch [448], Train Loss: 0.0151
# Epoch [18/20], Batch [449], Train Loss: 0.9299
# Epoch [18/20], Batch [450], Train Loss: 0.3855
# Epoch [18/20], Batch [451], Train Loss: 0.7212
# Epoch [18/20], Batch [452], Train Loss: 0.0046
# Epoch [18/20], Batch [453], Train Loss: 0.4099
# Epoch [18/20], Batch [454], Train Loss: 0.0045
# Epoch [18/20], Batch [455], Train Loss: 0.0008
# Epoch [18/20], Batch [456], Train Loss: 0.2561
# Epoch [18/20], Batch [457], Train Loss: 0.0164
# Epoch [18/20], Batch [458], Train Loss: 0.3651
# Epoch [18/20], Batch [459], Train Loss: 0.0047
# Epoch [18/20], Batch [460], Train Loss: 0.0134
# Epoch [18/20], Batch [461], Train Loss: 0.2920
# Epoch [18/20], Batch [462], Train Loss: 0.0133
# Epoch [18/20], Batch [463], Train Loss: 0.0224
# Epoch [18/20], Batch [464], Train Loss: 0.0084
# Epoch [18/20], Batch [465], Train Loss: 0.0130
# Epoch [18/20], Batch [466], Train Loss: 0.0136
# Epoch [18/20], Batch [467], Train Loss: 0.1956
# Epoch [18/20], Batch [468], Train Loss: 0.0030
# Epoch [18/20], Batch [469], Train Loss: 0.0028
# Epoch [18/20], Batch [470], Train Loss: 0.1217
# Epoch [18/20], Batch [471], Train Loss: 0.2105
# Epoch [18/20], Batch [472], Train Loss: 0.0076
# Epoch [18/20], Batch [473], Train Loss: 0.1266
# Epoch [18/20], Batch [474], Train Loss: 0.0085
# Epoch [18/20], Batch [475], Train Loss: 0.0038
# Epoch [18/20], Batch [476], Train Loss: 0.2367
# Epoch [18/20], Batch [477], Train Loss: 0.3964
# Epoch [18/20], Batch [478], Train Loss: -0.0566
# Epoch [18/20], Batch [479], Train Loss: 0.0062
# Epoch [18/20], Batch [480], Train Loss: 0.0697
# Epoch [18/20], Batch [481], Train Loss: 0.1460
# Epoch [18/20], Batch [482], Train Loss: 0.2261
# Epoch [18/20], Batch [483], Train Loss: 0.6169
# Epoch [18/20], Batch [484], Train Loss: 0.0039
# Epoch [18/20], Batch [485], Train Loss: 0.0063
# Epoch [18/20], Batch [486], Train Loss: 0.4466
# Epoch [18/20], Batch [487], Train Loss: 0.2066
# Epoch [18/20], Batch [488], Train Loss: 0.0049
# Epoch [18/20], Batch [489], Train Loss: 0.0044
# Epoch [18/20], Batch [490], Train Loss: 0.3146
# Epoch [18/20], Batch [491], Train Loss: 0.0073
# Epoch [18/20], Batch [492], Train Loss: 0.2069
# Epoch [18/20], Batch [493], Train Loss: 0.2345
# Epoch [18/20], Batch [494], Train Loss: 0.2343
# Epoch [18/20], Batch [495], Train Loss: 0.9981
# Epoch [18/20], Batch [496], Train Loss: 0.0023
# Epoch [18/20], Batch [497], Train Loss: 0.0027
# Epoch [18/20], Batch [498], Train Loss: 0.0034
# Epoch [18/20], Batch [499], Train Loss: -0.2532
# Epoch [18/20], Batch [500], Train Loss: 0.3918
# ...
# Epoch [20/20], Batch [1243], Train Loss: 0.0026
# Epoch [20/20], Batch [1244], Train Loss: 0.0018
# Epoch [20/20], Batch [1245], Train Loss: 0.0086
# Epoch [20/20], Batch [1246], Train Loss: 0.1313
# Epoch [20/20], Batch [1247], Train Loss: 0.0810
# Epoch [20/20], Batch [1248], Train Loss: 0.0007
# Epoch [20/20], Batch [1249], Train Loss: 0.0024
# Epoch [20/20], Batch [1250], Train Loss: 0.0095
# Epoch [20/20], Batch [1251], Train Loss: -0.1795
# Epoch [20/20], Batch [1252], Train Loss: 0.1787
# Epoch [20/20], Batch [1253], Train Loss: 0.0241
# Epoch [20/20], Batch [1254], Train Loss: 0.0021
# Epoch [20/20], Batch [1255], Train Loss: 0.0039
# Epoch [20/20], Batch [1256], Train Loss: 0.0025
# Epoch [20/20], Batch [1257], Train Loss: 0.0120
# Epoch [20/20], Batch [1258], Train Loss: 0.0654
# Epoch [20/20], Batch [1259], Train Loss: 0.0572
# Epoch [20/20], Batch [1260], Train Loss: 0.0054
# Epoch [20/20], Batch [1261], Train Loss: 0.0012
# Epoch [20/20], Batch [1262], Train Loss: 0.0177
# Epoch [20/20], Batch [1263], Train Loss: 0.0028
# Epoch [20/20], Batch [1264], Train Loss: 0.0081
# Epoch [20/20], Batch [1265], Train Loss: 0.0045
# Epoch [20/20], Batch [1266], Train Loss: 0.1802
# Epoch [20/20], Batch [1267], Train Loss: 0.0042
# Epoch [20/20], Batch [1268], Train Loss: 0.0005
# Epoch [20/20], Batch [1269], Train Loss: 0.0646
# Epoch [20/20], Batch [1270], Train Loss: 0.0558
# Epoch [20/20], Batch [1271], Train Loss: 0.5411
# Epoch [20/20], Batch [1272], Train Loss: 0.0019
# Epoch [20/20], Batch [1273], Train Loss: 0.0102
# Epoch [20/20], Batch [1274], Train Loss: 0.0001
# Epoch [20/20], Batch [1275], Train Loss: 0.3325
# Epoch [20/20], Batch [1276], Train Loss: 0.5284
# Epoch [20/20], Batch [1277], Train Loss: 0.0660
# Epoch [20/20], Batch [1278], Train Loss: 0.8650
# Epoch [20/20], Batch [1279], Train Loss: 0.0397
# Epoch [20/20], Batch [1280], Train Loss: 0.0839
# Epoch [20/20], Batch [1281], Train Loss: 0.0034
# Epoch [20/20], Batch [1282], Train Loss: 0.0132
# Epoch [20/20], Batch [1283], Train Loss: 0.0422
# Epoch [20/20], Batch [1284], Train Loss: 0.0015
# Epoch [20/20], Batch [1285], Train Loss: 0.0928
# Epoch [20/20], Batch [1286], Train Loss: 0.1160
# Epoch [20/20], Batch [1287], Train Loss: 0.4367
# Epoch [20/20], Batch [1288], Train Loss: 0.0724
# Epoch [20/20], Batch [1289], Train Loss: 0.0047
# Epoch [20/20], Batch [1290], Train Loss: 0.0860
# Epoch [20/20], Batch [1291], Train Loss: 0.0034
# Epoch [20/20], Batch [1292], Train Loss: 0.0041
# Epoch [20/20], Batch [1293], Train Loss: 0.0235
# Epoch [20/20], Batch [1294], Train Loss: 0.0373
# Epoch [20/20], Batch [1295], Train Loss: 0.0378
# Epoch [20/20], Batch [1296], Train Loss: 0.0050
# Epoch [20/20], Batch [1297], Train Loss: 0.0008
# Epoch [20/20], Batch [1298], Train Loss: 0.0044
# Epoch [20/20], Batch [1299], Train Loss: 0.0493
# Epoch [20/20], Batch [1460], Train Loss: 0.3316
# Epoch [20/20], Batch [1461], Train Loss: 0.0032
# Epoch [20/20], Batch [1462], Train Loss: 0.1194
# Epoch [20/20], Batch [1463], Train Loss: 0.0039
# Epoch [20/20], Batch [1464], Train Loss: 0.0077
# Epoch [20/20], Batch [1465], Train Loss: 0.3413
# Epoch [20/20], Batch [1466], Train Loss: 0.0021
# Epoch [20/20], Batch [1467], Train Loss: 0.0115
# Epoch [20/20], Batch [1468], Train Loss: 0.5298
# Epoch [20/20], Batch [1469], Train Loss: 0.2013
# Epoch [20/20], Batch [1470], Train Loss: 0.0010
# Epoch [20/20], Batch [1471], Train Loss: 0.1757
# Epoch [20/20], Batch [1472], Train Loss: 0.0080
# Epoch [20/20], Batch [1473], Train Loss: 0.2188
# Epoch [20/20], Batch [1474], Train Loss: 0.4740
# Epoch [20/20], Batch [1475], Train Loss: 0.5631
# Epoch [20/20], Batch [1476], Train Loss: 0.1479
# Epoch [20/20], Batch [1477], Train Loss: 0.1511
# Epoch [20/20], Batch [1478], Train Loss: 0.0142
# Epoch [20/20], Batch [1479], Train Loss: 0.0115
# Epoch [20/20], Batch [1480], Train Loss: 0.0029
# Epoch [20/20], Batch [1481], Train Loss: 0.0415
# Epoch [20/20], Batch [1482], Train Loss: 0.3668
# Epoch [20/20], Batch [1483], Train Loss: 0.0012
# Epoch [20/20], Batch [1484], Train Loss: 0.0056
# Epoch [20/20], Batch [1485], Train Loss: 0.1499
# Epoch [20/20], Batch [1486], Train Loss: 0.6265
# Epoch [20/20], Batch [1487], Train Loss: 0.0007
# Epoch [20/20], Batch [1488], Train Loss: 0.1199
# Epoch [20/20], Batch [1489], Train Loss: 0.0054
# Epoch [20/20], Batch [1490], Train Loss: 0.0029
# Epoch [20/20], Batch [1491], Train Loss: 0.0008
# Epoch [20/20], Batch [1492], Train Loss: 0.0033
# Epoch [20/20] completed, Avg Train Loss: 0.0860
# Epoch [20/20] completed, Avg Val Loss: 0.1913
# لاس validation بهبود نیافت (1/3)
# مدل نهایی ذخیره شد: finetuned.pt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-855f11e64946> in <cell line: 0>()
#      21         targets = torch.cat(targets)
#      22
# ---> 23         outputs = model(images)
#      24         outputs = outputs.log_softmax(2)
#      25         outputs = outputs.permute(1, 0, 2)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-6-77b6c9240209> in forward(self, x)
#      18     def forward(self, x):
#      19         for key in sorted(self.cnn.keys(), key=lambda k: int(k)):
# ---> 20             x = self.cnn[key](x)
#      21             if key in ['0', '2']:
#      22                 x = nn.functional.max_pool2d(x, 2)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-5-f6766ca4d472> in forward(self, x)
#       6
#       7     def forward(self, x):
# ----> 8         x = self.conv(x)
#       9         x = self.bn(x)
#      10         x = nn.functional.relu(x)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor
