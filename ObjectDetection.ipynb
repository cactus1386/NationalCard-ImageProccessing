# %%
! pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
import os
from IPython.display import display, Image
import glob

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TafTnLjXkvLUpxGZP8JU")
project = rf.workspace("id-card-vf1zl").project("idcardiran-tcuzs")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=30 imgsz=640
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 191MB/s]
# Ultralytics 8.3.73 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/IDCardIran-1/data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 20.7MB/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739041860.040767   10752 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739041860.119761   10752 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2119144  ultralytics.nn.modules.head.Detect           [8, [128, 256, 512]]
# Model summary: 225 layers, 11,138,696 parameters, 11,138,680 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 81.0MB/s]
# AMP: checks passed ✅
# train: Scanning /content/IDCardIran-1/train/labels... 792 images, 9 backgrounds, 0 corrupt: 100% 792/792 [00:00<00:00, 1793.71it/s]
# train: New cache created: /content/IDCardIran-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/IDCardIran-1/valid/labels... 68 images, 0 backgrounds, 0 corrupt: 100% 68/68 [00:00<00:00, 878.82it/s]
# val: New cache created: /content/IDCardIran-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      4.03G      1.668      3.018      1.343         92        640: 100% 50/50 [00:19<00:00,  2.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:03<00:00,  1.06s/it]
#                    all         68        536      0.835      0.937      0.958      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      4.03G      1.309      1.158      1.124         73        640: 100% 50/50 [00:16<00:00,  3.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.27it/s]
#                    all         68        536      0.934       0.94      0.978      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      4.01G      1.276     0.8908      1.112         76        640: 100% 50/50 [00:15<00:00,  3.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.85it/s]
#                    all         68        536      0.925      0.944      0.986      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      4.04G      1.251     0.7822       1.11        119        640: 100% 50/50 [00:15<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.91it/s]
#                    all         68        536      0.967      0.987      0.985      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      4.04G      1.218     0.7303      1.093         87        640: 100% 50/50 [00:15<00:00,  3.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.63it/s]
#                    all         68        536      0.966      0.995      0.985      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      4.04G      1.198     0.6909      1.081         58        640: 100% 50/50 [00:16<00:00,  3.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.76it/s]
#                    all         68        536      0.978      0.997      0.983      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      4.01G      1.162     0.6603       1.07         71        640: 100% 50/50 [00:17<00:00,  2.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.08it/s]
#                    all         68        536      0.979      0.988      0.987       0.81
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      3.92G      1.197     0.6497      1.086         85        640: 100% 50/50 [00:16<00:00,  2.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.68it/s]
#                    all         68        536      0.983      0.997      0.987      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      4.05G      1.158     0.6253      1.055         74        640: 100% 50/50 [00:16<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.56it/s]
#                    all         68        536      0.979      0.997      0.986      0.795
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      4.02G      1.174     0.6203      1.071        130        640: 100% 50/50 [00:16<00:00,  3.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.09it/s]
#                    all         68        536      0.978      0.998      0.988      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      3.87G       1.13     0.5931      1.056         97        640: 100% 50/50 [00:16<00:00,  2.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.43it/s]
#                    all         68        536      0.979      0.998      0.986      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      4.07G      1.122     0.5902      1.045         74        640: 100% 50/50 [00:16<00:00,  2.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.32it/s]
#                    all         68        536      0.981      0.998      0.988      0.802
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      4.01G      1.122     0.5824       1.05        128        640: 100% 50/50 [00:16<00:00,  2.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.22it/s]
#                    all         68        536      0.976      0.996      0.986      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30         4G      1.097     0.5631      1.047        113        640: 100% 50/50 [00:17<00:00,  2.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.48it/s]
#                    all         68        536      0.979      0.998      0.989      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      4.01G      1.076     0.5544      1.034         66        640: 100% 50/50 [00:16<00:00,  2.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.14it/s]
#                    all         68        536      0.982      0.998      0.987      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      4.01G      1.069     0.5345      1.032        125        640: 100% 50/50 [00:17<00:00,  2.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.25it/s]
#                    all         68        536      0.981      0.998      0.989      0.817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      4.03G      1.045     0.5304      1.022         95        640: 100% 50/50 [00:16<00:00,  2.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.03it/s]
#                    all         68        536      0.981      0.998      0.987      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      3.99G      1.054     0.5263      1.027        127        640: 100% 50/50 [00:16<00:00,  2.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.27it/s]
#                    all         68        536      0.982      0.998      0.989      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      4.06G      1.024     0.5026      1.017         84        640: 100% 50/50 [00:16<00:00,  3.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.28it/s]
#                    all         68        536      0.981      0.998      0.986      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      4.04G       1.01     0.5085     0.9998         86        640: 100% 50/50 [00:16<00:00,  3.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.87it/s]
#                    all         68        536      0.983      0.998      0.988      0.835
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      4.04G      1.011     0.4564      1.017         63        640: 100% 50/50 [00:17<00:00,  2.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  1.85it/s]
#                    all         68        536      0.983      0.998      0.986      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      4.04G     0.9811     0.4414      1.008         64        640: 100% 50/50 [00:16<00:00,  3.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.21it/s]
#                    all         68        536      0.982      0.998      0.987      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      4.05G     0.9633     0.4326     0.9976         64        640: 100% 50/50 [00:15<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.20it/s]
#                    all         68        536      0.982      0.998      0.986      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      4.04G     0.9635     0.4266     0.9952         64        640: 100% 50/50 [00:16<00:00,  3.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.40it/s]
#                    all         68        536      0.982      0.998      0.988      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      4.05G     0.9493     0.4191     0.9906         64        640: 100% 50/50 [00:16<00:00,  3.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.82it/s]
#                    all         68        536      0.983      0.998      0.988      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      4.04G     0.9541     0.4164     0.9982         61        640: 100% 50/50 [00:16<00:00,  3.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.20it/s]
#                    all         68        536      0.983      0.997      0.989      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      4.05G      0.932     0.4072     0.9854         54        640: 100% 50/50 [00:16<00:00,  3.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.51it/s]
#                    all         68        536      0.982      0.998      0.987      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      4.04G     0.9153     0.4026     0.9734         64        640: 100% 50/50 [00:16<00:00,  3.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.45it/s]
#                    all         68        536      0.982      0.998      0.986      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      4.05G     0.8914     0.3945      0.966         64        640: 100% 50/50 [00:16<00:00,  3.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.60it/s]
#                    all         68        536      0.983      0.998      0.987      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      3.88G     0.8919     0.3875       0.97         63        640: 100% 50/50 [00:16<00:00,  3.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.85it/s]
#                    all         68        536      0.982      0.998      0.987      0.843
#
# 30 epochs completed in 0.157 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.73 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.09it/s]
#                    all         68        536      0.982      0.998      0.986      0.843
#                Id-Card         67         67      0.985          1      0.995      0.936
#               Id-Card2         67         67      0.984          1      0.995      0.832
#               Id-Card3         68         68      0.997          1      0.995      0.833
#               Id-Card4         67         68      0.983      0.985      0.979      0.816
#               Id-Card5         66         66      0.965          1      0.968      0.832
#               Id-Card6         66         66       0.97          1      0.977      0.821
#               Id-Card7         67         67      0.985          1      0.993      0.835
#               Id-Card8         67         67      0.983          1      0.985      0.842
# Speed: 0.2ms preprocess, 5.0ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
Image(filename=f'runs/detect/train/confusion_matrix.png', width=600)

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images
# Out:
# Ultralytics 8.3.73 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/25 /content/IDCardIran-1/test/images/-001_jpg.rf.705fcfa0788a6d29bd8ba10cb1b13416.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 16.3ms
# image 2/25 /content/IDCardIran-1/test/images/-001_jpg.rf.7cdcad49e556bdc6cf315234a60395e4.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 16.3ms
# image 3/25 /content/IDCardIran-1/test/images/-1_jpeg.rf.463b30783dbb10d81cd13ee683585886.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 16.2ms
# image 4/25 /content/IDCardIran-1/test/images/-1_jpg.rf.62523fdbad99ba52925f7bcaf0ebb230.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 16.2ms
# image 5/25 /content/IDCardIran-1/test/images/-1_jpg.rf.916eec4e89c5a9eec8b453d9074e7c46.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 16.3ms
# image 6/25 /content/IDCardIran-1/test/images/-3_jpeg.rf.5152535f52a7781abfc362633cec8c23.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 16.3ms
# image 7/25 /content/IDCardIran-1/test/images/-_jpg.rf.669cea954ebef40b7c10a2a93494349f.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 8/25 /content/IDCardIran-1/test/images/A1-002-007_jpg.rf.71773750423cd691851526b5a790b6b2.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 9/25 /content/IDCardIran-1/test/images/A3-92-008_jpg.rf.f0b3f95837bc85cedabd5bcee76ba6f7.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 10/25 /content/IDCardIran-1/test/images/A5-156-006_jpg.rf.02f078596caf0d263a9cf9b75e346967.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 11/25 /content/IDCardIran-1/test/images/B4-111-008_jpg.rf.6f5b9ec08fc016f35a9ded966d3592af.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 12/25 /content/IDCardIran-1/test/images/C3-122-014_jpg.rf.f0ec8f1cf0e0363fd6fac13f741d6a1f.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 13/25 /content/IDCardIran-1/test/images/C4-91-063_jpg.rf.cab3aaf4ffd10ea7299a18b757689719.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 15.9ms
# image 14/25 /content/IDCardIran-1/test/images/D3-80-032_jpg.rf.d60cb282a1b92e19c5b159fa27898708.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 14.8ms
# image 15/25 /content/IDCardIran-1/test/images/IMG_20230816_114828_jpg.rf.e413a6faa98496e8252d281ab44e070d.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.9ms
# image 16/25 /content/IDCardIran-1/test/images/IMG_20230816_134741_jpg.rf.a5e204e16fd3e2f1bb295453f5fa9e66.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.9ms
# image 17/25 /content/IDCardIran-1/test/images/IMG_20230816_142252_jpg.rf.8db72e6ad93df3f510475195d9c5de75.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.8ms
# image 18/25 /content/IDCardIran-1/test/images/IMG_20230816_142904_jpg.rf.470049aa312b7e9e0e892f00dc9a34dd.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.8ms
# image 19/25 /content/IDCardIran-1/test/images/IMG_20230817_080336_jpg.rf.654a0ad0fdbb4f3e89d5500e7f4aece5.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.8ms
# image 20/25 /content/IDCardIran-1/test/images/IMG_20230817_081142_jpg.rf.14a2dcc529d29e66ada37e7924b2e17e.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 2 Id-Card6s, 1 Id-Card7, 1 Id-Card8, 10.8ms
# image 21/25 /content/IDCardIran-1/test/images/IMG_20230817_092323_jpg.rf.432774d74f01f741b4d8f08ce3f2c525.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.9ms
# image 22/25 /content/IDCardIran-1/test/images/IMG_20230817_100514_jpg.rf.e27145b8cc0fd56f16dd7e2ca1909ce5.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.9ms
# image 23/25 /content/IDCardIran-1/test/images/IMG_20230817_103747_jpg.rf.c1f1f9e88ca5a8d525415a5a58efa359.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.8ms
# image 24/25 /content/IDCardIran-1/test/images/idcard_54_jpg.rf.7ec1c4fa506b880d6f2834b7628e0b46.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 10.2ms
# image 25/25 /content/IDCardIran-1/test/images/msg177741039-163237-2-_jpg.rf.740194675103ddb2cddbb537df91ba4c.jpg: 640x640 1 Id-Card, 1 Id-Card2, 1 Id-Card3, 1 Id-Card4, 1 Id-Card5, 1 Id-Card6, 1 Id-Card7, 1 Id-Card8, 8.6ms
# Speed: 1.8ms preprocess, 13.6ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import display, Image

for img in glob.glob(f'runs/detect/predict/*.jpg')[:3]:
  display(Image(filename=img, height=600))
  print('\n')

# %%
from ultralytics import YOLO
import cv2

img = cv2.imread('./Dataset/D/17.jpg')

model = YOLO(model="best.pt")
result = model.predict(source=img, show=True, save=True, save_txt=True, conf=0.4)

for r in result:
    boxes = r.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0] 
        label = r.names[int(box.cls)]
        confidence = box.conf
        print(f"Label: {label}, Confidence: {confidence}, Coordinates: {x1}, {y1}, {x2}, {y2}")
# Out:
# 0: 288x640 (no detections), 122.8ms
# Speed: 5.5ms preprocess, 122.8ms inference, 0.0ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to h:\Machine Learning\ML-Models\runs\detect\predict4
# 0 label saved to h:\Machine Learning\ML-Models\runs\detect\predict4\labels
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
