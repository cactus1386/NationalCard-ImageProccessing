# %%
import cv2
import matplotlib.pyplot as plt
import easyocr

# %%
img = cv2.imread('../Dataset/D/8.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img_resized = cv2.resize(img, (0, 0), fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
denoised = cv2.fastNlMeansDenoising(img_resized, None, 20, 5, 20)
# plt.imshow(cv2.cvtColor(denoised, cv2.COLOR_BGR2RGB))

# %%
# adaptive_thresholded = cv2.adaptiveThreshold(
#     denoised, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2
# )
# plt.imshow(cv2.cvtColor(adaptive_thresholded, cv2.COLOR_BGR2RGB))

# %%
# from realesrgan import RealESRGAN

# sr_model = RealESRGAN("weights/realesrgan-x4plus.pth", device="cuda")
# sr_model.load_weights()
# enhanced_image = sr_model.enhance(cropped_card)

# %%
reader = easyocr.Reader(['fa'])
text = reader.readtext(img_resized)
print(text[1][-2])
print(text)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ١١ ١ ٠ ٢٨٢٧٢ ٣
# [[[[np.int32(455), np.int32(189)], [np.int32(559), np.int32(189)], [np.int32(559), np.int32(233)], [np.int32(455), np.int32(233)]], 'تیمسسسدی', np.float64(0.1276651834149125)], [[[np.int32(571), np.int32(269)], [np.int32(714), np.int32(269)], [np.int32(714), np.int32(296)], [np.int32(571), np.int32(296)]], '١١ ١ ٠ ٢٨٢٧٢ ٣', np.float64(0.12006522111467469)], [[[np.int32(732), np.int32(276)], [np.int32(822), np.int32(276)], [np.int32(822), np.int32(300)], [np.int32(732), np.int32(300)]], 'ممشاره مام', np.float64(0.24675739423497373)], [[[np.int32(648), np.int32(314)], [np.int32(712), np.int32(314)], [np.int32(712), np.int32(340)], [np.int32(648), np.int32(340)]], 'رولماز', np.float64(0.3259303877423245)], [[[np.int32(572), np.int32(392)], [np.int32(710), np.int32(392)], [np.int32(710), np.int32(416)], [np.int32(572), np.int32(416)]], '٢ ١٢٥٧،١٢،١', np.float64(0.2819366882234894)], [[[np.int32(670), np.int32(430)], [np.int32(710), np.int32(430)], [np.int32(710), np.int32(456)], [np.int32(670), np.int32(456)]], 'علٰی', np.float64(0.34391055299560175)], [[[np.int32(569), np.int32(463)], [np.int32(710), np.int32(463)], [np.int32(710), np.int32(491)], [np.int32(569), np.int32(491)]], '١٣٥٤،٠٥/١٣', np.float64(0.21672482353028807)], [[[np.float64(643.170867717451), np.float64(357.6221280326862)], [np.float64(711.7094020137752), np.float64(350.7119236327954)], [np.float64(712.829132282549), np.float64(375.3778719673138)], [np.float64(645.2905979862248), np.float64(382.2880763672046)]], 'الماسى', np.float64(0.4211023354971613)]]
